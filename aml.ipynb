# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.insert(0, '/content/drive/My Drive')


import matplotlib.pyplot as plt
import torchvision
from torchvision import transforms

# %%
from Cityscapes import Cityscapes
normalizer = transforms.Normalize(mean=(73.15, 82.90, 72.39), std=(47.67, 48.49, 47.73))

train_transform = transforms.Compose([transforms.ToTensor()])
eval_transform = transforms.Compose([transforms.ToTensor()])

train_dataset = Cityscapes('drive/MyDrive/', partition_type='A', split='train', transform=None)
test_dataset = Cityscapes('drive/MyDrive/', partition_type='A', split='val', transform=None)

i, l = train_dataset.__getitem__(1)
plt.imshow(i)
plt.show()
